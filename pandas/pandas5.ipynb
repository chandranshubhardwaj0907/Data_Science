# %%
import pandas as pd

# %%
#  Data Transformation

df = pd.read_excel("data2.xlsx")

# %%
df
# Out:
#          Actor Name       Genre                     Film    Year  \
# 0       Salman Khan      Action                   Sultan  2016.0
# 1        Aamir Khan       Drama                   Dangal  2016.0
# 2     Ranbir Kapoor     Romance  Yeh Jawaani Hai Deewani  2013.0
# 3     Ranveer Singh  Historical                Padmaavat  2018.0
# 4  Amitabh Bachchan    Thriller                     Pink  2016.0
# 5     Vicky Kaushal         War                      Uri  2019.0
# 6     Rajkummar Rao       Crime                   Shahid  2013.0
# 7            etc...         NaN                      NaN     NaN
#
#    Box Office (Cr)  IMDb Rating
# 0            623.0          7.0
# 1           2024.0          8.4
# 2            319.0          7.2
# 3            585.0          7.0
# 4             77.0          8.1
# 5            342.0          8.4
# 6              4.0          8.2
# 7              NaN          NaN

# %%
df.sort_values("Year")
# Out:
#          Actor Name       Genre                     Film    Year  \
# 2     Ranbir Kapoor     Romance  Yeh Jawaani Hai Deewani  2013.0
# 6     Rajkummar Rao       Crime                   Shahid  2013.0
# 0       Salman Khan      Action                   Sultan  2016.0
# 1        Aamir Khan       Drama                   Dangal  2016.0
# 4  Amitabh Bachchan    Thriller                     Pink  2016.0
# 3     Ranveer Singh  Historical                Padmaavat  2018.0
# 5     Vicky Kaushal         War                      Uri  2019.0
# 7            etc...         NaN                      NaN     NaN
#
#    Box Office (Cr)  IMDb Rating
# 2            319.0          7.2
# 6              4.0          8.2
# 0            623.0          7.0
# 1           2024.0          8.4
# 4             77.0          8.1
# 3            585.0          7.0
# 5            342.0          8.4
# 7              NaN          NaN

# %%
df.sort_values("Year" , ascending=False)
# Out:
#          Actor Name       Genre                     Film    Year  \
# 5     Vicky Kaushal         War                      Uri  2019.0
# 3     Ranveer Singh  Historical                Padmaavat  2018.0
# 0       Salman Khan      Action                   Sultan  2016.0
# 1        Aamir Khan       Drama                   Dangal  2016.0
# 4  Amitabh Bachchan    Thriller                     Pink  2016.0
# 2     Ranbir Kapoor     Romance  Yeh Jawaani Hai Deewani  2013.0
# 6     Rajkummar Rao       Crime                   Shahid  2013.0
# 7            etc...         NaN                      NaN     NaN
#
#    Box Office (Cr)  IMDb Rating
# 5            342.0          8.4
# 3            585.0          7.0
# 0            623.0          7.0
# 1           2024.0          8.4
# 4             77.0          8.1
# 2            319.0          7.2
# 6              4.0          8.2
# 7              NaN          NaN

# %%
df2 = df.sort_values(["Year" , "IMDb Rating"]).copy()

# %%
df2.reset_index(drop = True , inplace=True)

# %%
df2
# Out:
#          Actor Name       Genre                     Film    Year  \
# 2     Ranbir Kapoor     Romance  Yeh Jawaani Hai Deewani  2013.0
# 6     Rajkummar Rao       Crime                   Shahid  2013.0
# 0       Salman Khan      Action                   Sultan  2016.0
# 4  Amitabh Bachchan    Thriller                     Pink  2016.0
# 1        Aamir Khan       Drama                   Dangal  2016.0
# 3     Ranveer Singh  Historical                Padmaavat  2018.0
# 5     Vicky Kaushal         War                      Uri  2019.0
# 7            etc...         NaN                      NaN     NaN
#
#    Box Office (Cr)  IMDb Rating
# 2            319.0          7.2
# 6              4.0          8.2
# 0            623.0          7.0
# 4             77.0          8.1
# 1           2024.0          8.4
# 3            585.0          7.0
# 5            342.0          8.4
# 7              NaN          NaN

# %%
df2.sort_index()
# Out:
#          Actor Name       Genre                     Film    Year  \
# 0     Ranbir Kapoor     Romance  Yeh Jawaani Hai Deewani  2013.0
# 1     Rajkummar Rao       Crime                   Shahid  2013.0
# 2       Salman Khan      Action                   Sultan  2016.0
# 3  Amitabh Bachchan    Thriller                     Pink  2016.0
# 4        Aamir Khan       Drama                   Dangal  2016.0
# 5     Ranveer Singh  Historical                Padmaavat  2018.0
# 6     Vicky Kaushal         War                      Uri  2019.0
# 7            etc...         NaN                      NaN     NaN
#
#    Box Office (Cr)  IMDb Rating
# 0            319.0          7.2
# 1              4.0          8.2
# 2            623.0          7.0
# 3             77.0          8.1
# 4           2024.0          8.4
# 5            585.0          7.0
# 6            342.0          8.4
# 7              NaN          NaN

# %%
df2["rank"]  = df2["IMDb Rating"].rank(ascending=False,method="dense")

# %%
df2
# Out:
#          Actor Name       Genre                     Film    Year  \
# 0     Ranbir Kapoor     Romance  Yeh Jawaani Hai Deewani  2013.0
# 1     Rajkummar Rao       Crime                   Shahid  2013.0
# 2       Salman Khan      Action                   Sultan  2016.0
# 3  Amitabh Bachchan    Thriller                     Pink  2016.0
# 4        Aamir Khan       Drama                   Dangal  2016.0
# 5     Ranveer Singh  Historical                Padmaavat  2018.0
# 6     Vicky Kaushal         War                      Uri  2019.0
# 7            etc...         NaN                      NaN     NaN
#
#    Box Office (Cr)  IMDb Rating  rank
# 0            319.0          7.2   4.0
# 1              4.0          8.2   2.0
# 2            623.0          7.0   5.0
# 3             77.0          8.1   3.0
# 4           2024.0          8.4   1.0
# 5            585.0          7.0   5.0
# 6            342.0          8.4   1.0
# 7              NaN          NaN   NaN

# %%
df2
# Out:
#          Actor Name       Genre                     Film    Year  \
# 0     Ranbir Kapoor     Romance  Yeh Jawaani Hai Deewani  2013.0
# 1     Rajkummar Rao       Crime                   Shahid  2013.0
# 2       Salman Khan      Action                   Sultan  2016.0
# 3  Amitabh Bachchan    Thriller                     Pink  2016.0
# 4        Aamir Khan       Drama                   Dangal  2016.0
# 5     Ranveer Singh  Historical                Padmaavat  2018.0
# 6     Vicky Kaushal         War                      Uri  2019.0
# 7            etc...         NaN                      NaN     NaN
#
#    Box Office (Cr)  IMDb Rating  rank
# 0            319.0          7.2   4.0
# 1              4.0          8.2   2.0
# 2            623.0          7.0   5.0
# 3             77.0          8.1   3.0
# 4           2024.0          8.4   1.0
# 5            585.0          7.0   5.0
# 6            342.0          8.4   1.0
# 7              NaN          NaN   NaN

# %%
cols = ["Film"] + [col for col in df.columns if col != "Film"]
df2 = df2[cols]

# %%
df2
# Out:
#                       Film        Actor Name       Genre    Year  \
# 0  Yeh Jawaani Hai Deewani     Ranbir Kapoor     Romance  2013.0
# 1                   Shahid     Rajkummar Rao       Crime  2013.0
# 2                   Sultan       Salman Khan      Action  2016.0
# 3                     Pink  Amitabh Bachchan    Thriller  2016.0
# 4                   Dangal        Aamir Khan       Drama  2016.0
# 5                Padmaavat     Ranveer Singh  Historical  2018.0
# 6                      Uri     Vicky Kaushal         War  2019.0
# 7                      NaN            etc...         NaN     NaN
#
#    Box Office (Cr)  IMDb Rating
# 0            319.0          7.2
# 1              4.0          8.2
# 2            623.0          7.0
# 3             77.0          8.1
# 4           2024.0          8.4
# 5            585.0          7.0
# 6            342.0          8.4
# 7              NaN          NaN
